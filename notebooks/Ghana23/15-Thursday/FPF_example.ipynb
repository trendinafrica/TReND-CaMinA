# %% [markdown]
# <a href="https://colab.research.google.com/github/lauradriscoll/Comp_Neuro-ML_course/blob/main/notebooks/15-Thursday/FPF_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PART III. Finding Fixed Points:
#
# This notebook leverages **FixedPointFinder - A Tensorflow toolbox for finding fixed points and linearized dynamics in recurrent neural networks** [https://github.com/mattgolub/fixed-point-finder]
#
# If you are using FixedPointFinder in research to be published, please cite the software contribution in your publication:
#
# Golub and Sussillo (2018), "FixedPointFinder: A Tensorflow toolbox for identifying and characterizing fixed points in recurrent neural networks," Journal of Open Source Software, 3(31), 1003, https://doi.org/10.21105/joss.01003 .

# %%
! git clone https://github.com/mattgolub/fixed-point-finder.git
! git clone https://github.com/mattgolub/recurrent-whisperer.git
# Out:
# Cloning into 'fixed-point-finder'...
# remote: Enumerating objects: 914, done.
# remote: Counting objects: 100% (237/237), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 914 (delta 174), reused 184 (delta 137), pack-reused 677
# Receiving objects: 100% (914/914), 607.08 KiB | 4.98 MiB/s, done.
# Resolving deltas: 100% (555/555), done.
# Cloning into 'recurrent-whisperer'...
# remote: Enumerating objects: 984, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 984 (delta 26), reused 37 (delta 15), pack-reused 931
# Receiving objects: 100% (984/984), 438.33 KiB | 7.83 MiB/s, done.
# Resolving deltas: 100% (643/643), done.

# %%
! pip install tensorflow==2.8.0

# Already satisfied
# ! pip install PyYAML==6.0

# Exact versions are not that important
# ! pip install numpy==1.24.3 scipy==1.10.1 scikit-learn==1.2.2 matplotlib==3.7.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.8.0
#   Downloading tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (23.3.3)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (3.8.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8.0)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (16.0.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8.0)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 66.7 MB/s eta 0:00:00
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8.0)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 32.2 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow==2.8.0)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 50.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.54.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8.0) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.27.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 65.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.2.2)
# Installing collected packages: tf-estimator-nightly, keras, tensorboard-data-server, keras-preprocessing, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
#     Uninstalling tensorboard-data-server-0.7.0:
#       Successfully uninstalled tensorboard-data-server-0.7.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.2
#     Uninstalling tensorboard-2.12.2:
#       Successfully uninstalled tensorboard-2.12.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# Successfully installed google-auth-oauthlib-0.4.6 keras-2.8.0 keras-preprocessing-1.1.2 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorflow-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
import sys, os
import numpy as np

addpath = lambda dir: sys.path.insert(0, os.path.join('/content/', dir))
addpath('recurrent-whisperer')
addpath('fixed-point-finder')
addpath('fixed-point-finder/example')

from FlipFlop import FlipFlop
from run_FlipFlop import train_FlipFlop #, find_fixed_points
from FixedPointFinder import FixedPointFinder
from FixedPoints import FixedPoints
from plot_utils import plot_fps

# %% [markdown]
# ## Step 1: Train an RNN to solve the 3-bit memory task

# %%
model, valid_predictions = train_FlipFlop(train_mode=1)
# Out:
# Creating run directory: ./logs/06862fd7da.
# Attempting to build TF model on gpu:0
#
# Placing CPU-only ops on cpu:0
# /content/fixed-point-finder/example/FlipFlop.py:154: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   self.rnn_cell = tf1.nn.rnn_cell.LSTMCell(n_hidden)
# /usr/local/lib/python3.10/dist-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:984: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   self._kernel = self.add_variable(
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:992: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /usr/local/lib/python3.10/dist-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:993: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   self._bias = self.add_variable(
# Initializing new run (06862fd7da).
#
# Trainable variables:
# 	RecurrentWhisperer/lstm_cell/kernel:0: (19, 64)
# 	RecurrentWhisperer/lstm_cell/bias:0: (64,)
# 	RecurrentWhisperer/W_out:0: (16, 3)
# 	RecurrentWhisperer/b_out:0: (3,)
#
#
# Total run time time: 5.75s.
# 	0.1% (4.75ms): setup_hps
# 	0.1% (4.64ms): _setup_run_dir
# 	0.0% (1.59ms): set_random_seed
# 	0.0% (251us): init AdaptiveLearningRate
# 	0.0% (16.2us): init AdaptiveGradNormClip
# 	1.2% (71.2ms): _setup_records
# 	28.5% (1.64s): _setup_model
# 	47.0% (2.70s): _setup_optimizer
# 	0.0% (94.2us): _setup_visualizations
# 	5.6% (321ms): _setup_tensorboard
# 	4.5% (257ms): _setup_savers
# 	0.4% (24.7ms): _setup_session
# 	12.6% (724ms): initialize_or_restore
#
# 	Updating Tensorboard images.
# Entering training loop.
# Epoch 1 (step 1):
# 	Learning rate: 1.00e+00
# 	Training loss: 1.03e+00
# 	Improvement: nan
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 4.51s. [ prep data: 3.2% (147ms); batching: 0.0% (18.6us); train: 95.4% (4.31s); ltl: 1.3% (58.1ms); lvl: 0.0% (11.2us); visualize: 0.0% (293us); terminate: 0.0% (113us); ]
#
# Epoch 2 (step 2):
# 	Learning rate: 1.00e+00
# 	Training loss: 8.43e-01
# 	Improvement: 1.83e-01
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 121ms. [ prep data: 53.7% (65.3ms); batching: 0.0% (16.2us); train: 44.4% (53.9ms); ltl: 0.6% (688us); lvl: 0.0% (22.4us); visualize: 0.1% (180us); terminate: 0.1% (115us); ]
#
# Epoch 3 (step 3):
# 	Learning rate: 1.00e+00
# 	Training loss: 7.44e-01
# 	Improvement: 9.88e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 139ms. [ prep data: 60.8% (84.5ms); batching: 0.0% (18.8us); train: 37.8% (52.5ms); ltl: 0.9% (1.18ms); lvl: 0.0% (8.58us); visualize: 0.2% (261us); terminate: 0.1% (110us); ]
#
# Epoch 4 (step 4):
# 	Learning rate: 1.00e+00
# 	Training loss: 6.09e-01
# 	Improvement: 1.36e-01
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 120ms. [ prep data: 62.3% (74.7ms); batching: 0.0% (16.7us); train: 35.7% (42.8ms); ltl: 0.7% (889us); lvl: 0.0% (9.06us); visualize: 0.2% (196us); terminate: 0.1% (109us); ]
#
# Epoch 5 (step 5):
# 	Learning rate: 1.00e+00
# 	Training loss: 5.07e-01
# 	Improvement: 1.02e-01
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 126ms. [ prep data: 51.6% (64.8ms); batching: 0.0% (16.9us); train: 47.0% (59.1ms); ltl: 0.9% (1.09ms); lvl: 0.0% (8.58us); visualize: 0.2% (237us); terminate: 0.1% (117us); ]
#
# Epoch 6 (step 6):
# 	Learning rate: 1.00e+00
# 	Training loss: 4.36e-01
# 	Improvement: 7.11e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 122ms. [ prep data: 62.2% (76.1ms); batching: 0.0% (16.0us); train: 35.6% (43.6ms); ltl: 0.8% (997us); lvl: 0.0% (9.06us); visualize: 0.2% (220us); terminate: 0.1% (111us); ]
#
# Epoch 7 (step 7):
# 	Learning rate: 1.05e+00
# 	Training loss: 3.89e-01
# 	Improvement: 4.61e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 118ms. [ prep data: 56.7% (66.7ms); batching: 0.0% (16.2us); train: 40.9% (48.1ms); ltl: 0.9% (1.02ms); lvl: 0.0% (6.68us); visualize: 0.2% (237us); terminate: 0.1% (88.9us); ]
#
# Epoch 8 (step 8):
# 	Learning rate: 1.05e+00
# 	Training loss: 3.82e-01
# 	Improvement: 7.22e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 153ms. [ prep data: 68.7% (105ms); batching: 0.0% (23.4us); train: 29.6% (45.3ms); ltl: 0.7% (1.10ms); lvl: 0.0% (7.39us); visualize: 0.2% (245us); terminate: 0.1% (108us); ]
#
# Epoch 9 (step 9):
# 	Learning rate: 1.05e+00
# 	Training loss: 3.77e-01
# 	Improvement: 5.42e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 145ms. [ prep data: 68.5% (99.0ms); batching: 0.0% (16.5us); train: 29.4% (42.5ms); ltl: 0.7% (989us); lvl: 0.0% (8.11us); visualize: 0.3% (494us); terminate: 0.1% (106us); ]
#
# Epoch 10 (step 10):
# 	Learning rate: 1.05e+00
# 	Training loss: 4.01e-01
# 	Improvement: -2.41e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 181ms. [ prep data: 76.0% (137ms); batching: 0.0% (11.9us); train: 23.1% (41.8ms); ltl: 0.6% (1.03ms); lvl: 0.0% (7.39us); visualize: 0.1% (251us); terminate: 0.1% (94.9us); ]
#
# Epoch 11 (step 11):
# 	Learning rate: 1.05e+00
# 	Training loss: 3.78e-01
# 	Improvement: 2.28e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 132ms. [ prep data: 68.3% (90.4ms); batching: 0.0% (12.9us); train: 29.8% (39.4ms); ltl: 0.7% (963us); lvl: 0.0% (7.39us); visualize: 0.2% (209us); terminate: 0.1% (87.7us); ]
#
# Epoch 12 (step 12):
# 	Learning rate: 1.05e+00
# 	Training loss: 3.72e-01
# 	Improvement: 6.62e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 127ms. [ prep data: 64.0% (81.1ms); batching: 0.0% (11.2us); train: 34.2% (43.3ms); ltl: 0.9% (1.10ms); lvl: 0.0% (6.91us); visualize: 0.2% (253us); terminate: 0.1% (84.2us); ]
#
# Epoch 13 (step 13):
# 	Learning rate: 1.05e+00
# 	Training loss: 3.60e-01
# 	Improvement: 1.14e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 117ms. [ prep data: 61.5% (72.2ms); batching: 0.0% (12.6us); train: 36.2% (42.5ms); ltl: 0.9% (1.03ms); lvl: 0.0% (7.87us); visualize: 0.2% (253us); terminate: 0.1% (85.1us); ]
#
# Epoch 14 (step 14):
# 	Learning rate: 1.05e+00
# 	Training loss: 3.44e-01
# 	Improvement: 1.65e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 129ms. [ prep data: 65.6% (84.9ms); batching: 0.0% (11.4us); train: 32.1% (41.5ms); ltl: 0.8% (993us); lvl: 0.0% (6.91us); visualize: 0.3% (371us); terminate: 0.2% (211us); ]
#
# Epoch 15 (step 15):
# 	Learning rate: 1.05e+00
# 	Training loss: 3.41e-01
# 	Improvement: 2.55e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 133ms. [ prep data: 62.1% (82.8ms); batching: 0.0% (10.0us); train: 35.3% (47.1ms); ltl: 1.4% (1.87ms); lvl: 0.0% (11.0us); visualize: 0.2% (211us); terminate: 0.1% (122us); ]
#
# Epoch 16 (step 16):
# 	Learning rate: 1.11e+00
# 	Training loss: 3.26e-01
# 	Improvement: 1.47e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 109ms. [ prep data: 60.3% (65.7ms); batching: 0.0% (11.0us); train: 37.5% (40.8ms); ltl: 0.9% (942us); lvl: 0.0% (5.01us); visualize: 0.2% (254us); terminate: 0.1% (80.8us); ]
#
# Epoch 17 (step 17):
# 	Learning rate: 1.11e+00
# 	Training loss: 2.96e-01
# 	Improvement: 3.05e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 155ms. [ prep data: 68.9% (107ms); batching: 0.0% (12.4us); train: 29.2% (45.3ms); ltl: 0.6% (909us); lvl: 0.0% (7.15us); visualize: 0.3% (398us); terminate: 0.1% (81.1us); ]
#
# Epoch 18 (step 18):
# 	Learning rate: 1.11e+00
# 	Training loss: 2.80e-01
# 	Improvement: 1.57e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 118ms. [ prep data: 66.1% (77.8ms); batching: 0.0% (11.4us); train: 32.7% (38.4ms); ltl: 0.8% (893us); lvl: 0.0% (6.68us); visualize: 0.2% (239us); terminate: 0.1% (96.8us); ]
#
# Epoch 19 (step 19):
# 	Learning rate: 1.11e+00
# 	Training loss: 2.55e-01
# 	Improvement: 2.53e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 225ms. [ prep data: 69.3% (156ms); batching: 0.0% (13.6us); train: 30.0% (67.5ms); ltl: 0.4% (1000us); lvl: 0.0% (7.39us); visualize: 0.1% (247us); terminate: 0.0% (90.8us); ]
#
# Epoch 20 (step 20):
# 	Learning rate: 1.11e+00
# 	Training loss: 2.32e-01
# 	Improvement: 2.32e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 208ms. [ prep data: 65.9% (137ms); batching: 0.0% (13.4us); train: 32.5% (67.5ms); ltl: 0.5% (949us); lvl: 0.0% (14.1us); visualize: 0.1% (251us); terminate: 0.0% (90.8us); ]
#
# Epoch 21 (step 21):
# 	Learning rate: 1.17e+00
# 	Training loss: 2.19e-01
# 	Improvement: 1.25e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 190ms. [ prep data: 69.5% (132ms); batching: 0.0% (12.9us); train: 29.8% (56.6ms); ltl: 0.4% (852us); lvl: 0.0% (6.68us); visualize: 0.1% (202us); terminate: 0.0% (85.4us); ]
#
# Epoch 22 (step 22):
# 	Learning rate: 1.17e+00
# 	Training loss: 1.91e-01
# 	Improvement: 2.79e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 149ms. [ prep data: 69.3% (103ms); batching: 0.0% (9.54us); train: 29.7% (44.2ms); ltl: 0.7% (970us); lvl: 0.0% (8.82us); visualize: 0.2% (236us); terminate: 0.1% (97.5us); ]
#
# Epoch 23 (step 23):
# 	Learning rate: 1.17e+00
# 	Training loss: 1.73e-01
# 	Improvement: 1.82e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 143ms. [ prep data: 67.3% (96.3ms); batching: 0.0% (16.7us); train: 30.9% (44.2ms); ltl: 0.6% (856us); lvl: 0.0% (9.06us); visualize: 0.1% (194us); terminate: 0.1% (110us); ]
#
# Epoch 24 (step 24):
# 	Learning rate: 1.17e+00
# 	Training loss: 1.47e-01
# 	Improvement: 2.61e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 118ms. [ prep data: 56.6% (66.7ms); batching: 0.0% (15.7us); train: 41.3% (48.6ms); ltl: 0.8% (923us); lvl: 0.0% (9.30us); visualize: 0.2% (200us); terminate: 0.1% (134us); ]
#
# Epoch 25 (step 25):
# 	Learning rate: 1.17e+00
# 	Training loss: 1.28e-01
# 	Improvement: 1.91e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 115ms. [ prep data: 57.2% (65.9ms); batching: 0.0% (17.4us); train: 40.3% (46.4ms); ltl: 1.1% (1.26ms); lvl: 0.0% (8.82us); visualize: 0.2% (231us); terminate: 0.1% (109us); ]
#
# Epoch 26 (step 26):
# 	Learning rate: 1.23e+00
# 	Training loss: 1.17e-01
# 	Improvement: 1.10e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 192ms. [ prep data: 63.7% (122ms); batching: 0.0% (16.2us); train: 34.6% (66.6ms); ltl: 0.6% (1.15ms); lvl: 0.0% (9.06us); visualize: 0.1% (252us); terminate: 0.1% (133us); ]
#
# Epoch 27 (step 27):
# 	Learning rate: 1.23e+00
# 	Training loss: 1.01e-01
# 	Improvement: 1.56e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 201ms. [ prep data: 59.8% (120ms); batching: 0.0% (19.3us); train: 37.7% (75.9ms); ltl: 1.6% (3.15ms); lvl: 0.0% (9.78us); visualize: 0.2% (344us); terminate: 0.1% (122us); ]
#
# Epoch 28 (step 28):
# 	Learning rate: 1.23e+00
# 	Training loss: 8.82e-02
# 	Improvement: 1.30e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 231ms. [ prep data: 65.0% (150ms); batching: 0.0% (20.5us); train: 34.2% (79.0ms); ltl: 0.6% (1.33ms); lvl: 0.0% (9.30us); visualize: 0.1% (318us); terminate: 0.0% (112us); ]
#
# Epoch 29 (step 29):
# 	Learning rate: 1.23e+00
# 	Training loss: 7.56e-02
# 	Improvement: 1.26e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 231ms. [ prep data: 67.1% (155ms); batching: 0.0% (14.8us); train: 31.4% (72.7ms); ltl: 0.4% (1.03ms); lvl: 0.0% (7.87us); visualize: 0.1% (286us); terminate: 0.0% (107us); ]
#
# Epoch 30 (step 30):
# 	Learning rate: 1.23e+00
# 	Training loss: 6.49e-02
# 	Improvement: 1.07e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 223ms. [ prep data: 61.5% (137ms); batching: 0.0% (15.5us); train: 36.3% (80.8ms); ltl: 0.5% (1.03ms); lvl: 0.0% (8.34us); visualize: 0.8% (1.89ms); terminate: 0.0% (94.7us); ]
#
# Epoch 31 (step 31):
# 	Learning rate: 1.29e+00
# 	Training loss: 5.64e-02
# 	Improvement: 8.45e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 261ms. [ prep data: 68.1% (178ms); batching: 0.0% (13.6us); train: 30.0% (78.2ms); ltl: 1.7% (4.46ms); lvl: 0.0% (7.87us); visualize: 0.1% (330us); terminate: 0.0% (94.2us); ]
#
# Epoch 32 (step 32):
# 	Learning rate: 1.29e+00
# 	Training loss: 4.59e-02
# 	Improvement: 1.05e-02
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 224ms. [ prep data: 65.2% (146ms); batching: 0.0% (13.1us); train: 34.0% (76.2ms); ltl: 0.6% (1.25ms); lvl: 0.0% (6.91us); visualize: 0.1% (318us); terminate: 0.0% (98.0us); ]
#
# Epoch 33 (step 33):
# 	Learning rate: 1.29e+00
# 	Training loss: 3.80e-02
# 	Improvement: 7.92e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 233ms. [ prep data: 64.6% (150ms); batching: 0.0% (13.8us); train: 34.5% (80.4ms); ltl: 0.6% (1.30ms); lvl: 0.0% (6.68us); visualize: 0.1% (299us); terminate: 0.0% (104us); ]
#
# Epoch 34 (step 34):
# 	Learning rate: 1.29e+00
# 	Training loss: 3.10e-02
# 	Improvement: 7.01e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 242ms. [ prep data: 65.7% (159ms); batching: 0.0% (14.5us); train: 33.5% (81.0ms); ltl: 0.5% (1.25ms); lvl: 0.0% (7.39us); visualize: 0.1% (242us); terminate: 0.0% (93.5us); ]
#
# Epoch 35 (step 35):
# 	Learning rate: 1.29e+00
# 	Training loss: 2.31e-02
# 	Improvement: 7.90e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 245ms. [ prep data: 64.8% (159ms); batching: 0.0% (14.3us); train: 34.5% (84.5ms); ltl: 0.4% (1.06ms); lvl: 0.0% (7.39us); visualize: 0.1% (259us); terminate: 0.0% (95.1us); ]
#
# Epoch 36 (step 36):
# 	Learning rate: 1.36e+00
# 	Training loss: 1.86e-02
# 	Improvement: 4.51e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 235ms. [ prep data: 64.5% (151ms); batching: 0.0% (15.0us); train: 34.8% (81.7ms); ltl: 0.4% (993us); lvl: 0.0% (7.87us); visualize: 0.1% (239us); terminate: 0.0% (101us); ]
#
# Epoch 37 (step 37):
# 	Learning rate: 1.36e+00
# 	Training loss: 1.49e-02
# 	Improvement: 3.68e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 249ms. [ prep data: 60.6% (151ms); batching: 0.0% (16.0us); train: 36.8% (91.7ms); ltl: 1.7% (4.12ms); lvl: 0.0% (7.39us); visualize: 0.1% (260us); terminate: 0.0% (99.4us); ]
#
# Epoch 38 (step 38):
# 	Learning rate: 1.36e+00
# 	Training loss: 1.24e-02
# 	Improvement: 2.57e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 200ms. [ prep data: 66.5% (133ms); batching: 0.0% (14.5us); train: 32.5% (65.2ms); ltl: 0.6% (1.26ms); lvl: 0.0% (7.15us); visualize: 0.1% (290us); terminate: 0.0% (93.2us); ]
#
# Epoch 39 (step 39):
# 	Learning rate: 1.36e+00
# 	Training loss: 1.04e-02
# 	Improvement: 1.97e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 215ms. [ prep data: 58.2% (125ms); batching: 0.0% (14.3us); train: 38.4% (82.6ms); ltl: 0.6% (1.24ms); lvl: 0.0% (7.87us); visualize: 0.2% (325us); terminate: 0.0% (94.2us); ]
#
# Epoch 40 (step 40):
# 	Learning rate: 1.36e+00
# 	Training loss: 8.07e-03
# 	Improvement: 2.32e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 193ms. [ prep data: 66.8% (129ms); batching: 0.0% (12.2us); train: 29.8% (57.6ms); ltl: 0.7% (1.30ms); lvl: 0.0% (7.63us); visualize: 0.2% (306us); terminate: 0.1% (112us); ]
#
# Epoch 41 (step 41):
# 	Learning rate: 1.43e+00
# 	Training loss: 7.97e-03
# 	Improvement: 1.02e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 208ms. [ prep data: 67.4% (140ms); batching: 0.0% (15.5us); train: 30.8% (63.9ms); ltl: 0.6% (1.28ms); lvl: 0.0% (7.15us); visualize: 0.2% (350us); terminate: 0.0% (97.8us); ]
#
# Epoch 42 (step 42):
# 	Learning rate: 1.43e+00
# 	Training loss: 8.27e-03
# 	Improvement: -3.08e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 202ms. [ prep data: 63.2% (127ms); batching: 0.0% (14.1us); train: 35.8% (72.2ms); ltl: 0.7% (1.32ms); lvl: 0.0% (6.91us); visualize: 0.2% (336us); terminate: 0.0% (90.8us); ]
#
# Epoch 43 (step 43):
# 	Learning rate: 1.43e+00
# 	Training loss: 7.11e-03
# 	Improvement: 1.17e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 198ms. [ prep data: 65.8% (130ms); batching: 0.0% (16.2us); train: 32.0% (63.3ms); ltl: 0.7% (1.29ms); lvl: 0.0% (6.91us); visualize: 0.8% (1.65ms); terminate: 0.0% (95.8us); ]
#
# Epoch 44 (step 44):
# 	Learning rate: 1.43e+00
# 	Training loss: 6.38e-03
# 	Improvement: 7.28e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 196ms. [ prep data: 63.7% (125ms); batching: 0.0% (13.8us); train: 34.1% (67.0ms); ltl: 0.6% (1.23ms); lvl: 0.0% (7.39us); visualize: 0.2% (344us); terminate: 0.7% (1.46ms); ]
#
# Epoch 45 (step 45):
# 	Learning rate: 1.43e+00
# 	Training loss: 5.95e-03
# 	Improvement: 4.27e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 207ms. [ prep data: 66.7% (138ms); batching: 0.0% (16.0us); train: 31.9% (66.1ms); ltl: 0.6% (1.30ms); lvl: 0.0% (6.91us); visualize: 0.2% (316us); terminate: 0.0% (88.9us); ]
#
# Epoch 46 (step 46):
# 	Learning rate: 1.43e+00
# 	Training loss: 5.67e-03
# 	Improvement: 2.78e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 192ms. [ prep data: 69.3% (133ms); batching: 0.0% (14.1us); train: 28.5% (54.9ms); ltl: 0.9% (1.69ms); lvl: 0.0% (6.68us); visualize: 0.2% (316us); terminate: 0.1% (99.2us); ]
#
# Epoch 47 (step 47):
# 	Learning rate: 1.43e+00
# 	Training loss: 5.16e-03
# 	Improvement: 5.20e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 237ms. [ prep data: 60.7% (144ms); batching: 0.0% (16.7us); train: 38.6% (91.2ms); ltl: 0.5% (1.08ms); lvl: 0.0% (9.06us); visualize: 0.1% (247us); terminate: 0.1% (154us); ]
#
# Epoch 48 (step 48):
# 	Learning rate: 1.51e+00
# 	Training loss: 4.09e-03
# 	Improvement: 1.06e-03
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 206ms. [ prep data: 64.0% (132ms); batching: 0.0% (18.6us); train: 33.7% (69.3ms); ltl: 1.3% (2.61ms); lvl: 0.0% (8.82us); visualize: 0.2% (319us); terminate: 0.1% (112us); ]
#
# Epoch 49 (step 49):
# 	Learning rate: 1.51e+00
# 	Training loss: 4.09e-03
# 	Improvement: 7.03e-07
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 229ms. [ prep data: 65.0% (149ms); batching: 0.0% (17.9us); train: 33.7% (77.2ms); ltl: 0.4% (832us); lvl: 0.0% (7.63us); visualize: 0.1% (207us); terminate: 0.0% (113us); ]
#
# Epoch 50 (step 50):
# 	Learning rate: 1.51e+00
# 	Training loss: 3.92e-03
# 	Improvement: 1.73e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 211ms. [ prep data: 60.6% (128ms); batching: 0.0% (18.4us); train: 37.8% (79.7ms); ltl: 0.5% (1.00ms); lvl: 0.0% (8.34us); visualize: 0.1% (246us); terminate: 0.0% (99.2us); ]
#
# Epoch 51 (step 51):
# 	Learning rate: 1.51e+00
# 	Training loss: 3.36e-03
# 	Improvement: 5.56e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 208ms. [ prep data: 63.4% (132ms); batching: 0.0% (16.7us); train: 34.8% (72.4ms); ltl: 0.6% (1.31ms); lvl: 0.0% (8.11us); visualize: 0.1% (310us); terminate: 0.0% (103us); ]
#
# Epoch 52 (step 52):
# 	Learning rate: 1.51e+00
# 	Training loss: 2.88e-03
# 	Improvement: 4.79e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 226ms. [ prep data: 66.4% (150ms); batching: 0.0% (13.6us); train: 31.6% (71.4ms); ltl: 0.8% (1.73ms); lvl: 0.0% (7.63us); visualize: 0.1% (325us); terminate: 0.0% (96.3us); ]
#
# Epoch 53 (step 53):
# 	Learning rate: 1.59e+00
# 	Training loss: 2.99e-03
# 	Improvement: -1.05e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 176ms. [ prep data: 70.6% (124ms); batching: 0.0% (15.7us); train: 28.0% (49.4ms); ltl: 0.4% (766us); lvl: 0.0% (5.96us); visualize: 0.1% (197us); terminate: 0.0% (84.9us); ]
#
# Epoch 54 (step 54):
# 	Learning rate: 1.59e+00
# 	Training loss: 2.49e-03
# 	Improvement: 4.93e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 187ms. [ prep data: 72.6% (136ms); batching: 0.0% (11.4us); train: 26.1% (48.8ms); ltl: 0.4% (808us); lvl: 0.0% (7.15us); visualize: 0.1% (202us); terminate: 0.0% (84.6us); ]
#
# Epoch 55 (step 55):
# 	Learning rate: 1.59e+00
# 	Training loss: 2.17e-03
# 	Improvement: 3.21e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 105ms. [ prep data: 60.2% (63.3ms); batching: 0.0% (11.7us); train: 37.2% (39.1ms); ltl: 0.9% (984us); lvl: 0.0% (6.20us); visualize: 0.2% (198us); terminate: 0.1% (85.4us); ]
#
# Epoch 56 (step 56):
# 	Learning rate: 1.59e+00
# 	Training loss: 1.70e-03
# 	Improvement: 4.74e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 145ms. [ prep data: 68.6% (99.4ms); batching: 0.0% (12.6us); train: 30.4% (44.0ms); ltl: 0.7% (996us); lvl: 0.0% (5.25us); visualize: 0.2% (255us); terminate: 0.1% (89.9us); ]
#
# Epoch 57 (step 57):
# 	Learning rate: 1.59e+00
# 	Training loss: 1.63e-03
# 	Improvement: 6.87e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 124ms. [ prep data: 60.6% (75.0ms); batching: 0.0% (12.4us); train: 38.1% (47.1ms); ltl: 0.8% (952us); lvl: 0.0% (7.15us); visualize: 0.2% (302us); terminate: 0.1% (87.7us); ]
#
# Epoch 58 (step 58):
# 	Learning rate: 1.59e+00
# 	Training loss: 1.28e-03
# 	Improvement: 3.53e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 181ms. [ prep data: 67.8% (123ms); batching: 0.0% (12.4us); train: 31.4% (56.9ms); ltl: 0.5% (839us); lvl: 0.0% (6.91us); visualize: 0.1% (262us); terminate: 0.0% (84.2us); ]
#
# Epoch 59 (step 59):
# 	Learning rate: 1.67e+00
# 	Training loss: 1.12e-03
# 	Improvement: 1.54e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 112ms. [ prep data: 65.0% (72.8ms); batching: 0.0% (10.7us); train: 33.5% (37.5ms); ltl: 1.0% (1.13ms); lvl: 0.0% (5.96us); visualize: 0.2% (242us); terminate: 0.1% (73.9us); ]
#
# Epoch 60 (step 60):
# 	Learning rate: 1.67e+00
# 	Training loss: 1.20e-03
# 	Improvement: -7.38e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 113ms. [ prep data: 59.0% (66.5ms); batching: 0.0% (11.2us); train: 38.3% (43.2ms); ltl: 1.1% (1.24ms); lvl: 0.0% (6.68us); visualize: 0.4% (398us); terminate: 0.1% (107us); ]
#
# Epoch 61 (step 61):
# 	Learning rate: 1.67e+00
# 	Training loss: 9.90e-04
# 	Improvement: 2.08e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 121ms. [ prep data: 67.0% (81.0ms); batching: 0.0% (11.9us); train: 31.4% (37.9ms); ltl: 1.2% (1.43ms); lvl: 0.0% (5.72us); visualize: 0.2% (260us); terminate: 0.1% (82.0us); ]
#
# Epoch 62 (step 62):
# 	Learning rate: 1.67e+00
# 	Training loss: 1.01e-03
# 	Improvement: -1.85e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 178ms. [ prep data: 76.2% (136ms); batching: 0.0% (11.7us); train: 22.2% (39.5ms); ltl: 0.6% (1.05ms); lvl: 0.0% (6.91us); visualize: 0.1% (210us); terminate: 0.1% (89.2us); ]
#
# Epoch 63 (step 63):
# 	Learning rate: 1.67e+00
# 	Training loss: 1.00e-03
# 	Improvement: 6.65e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 122ms. [ prep data: 64.1% (78.3ms); batching: 0.0% (11.7us); train: 33.1% (40.5ms); ltl: 0.8% (997us); lvl: 0.0% (5.72us); visualize: 0.3% (376us); terminate: 0.1% (90.8us); ]
#
# Epoch 64 (step 64):
# 	Learning rate: 1.67e+00
# 	Training loss: 9.06e-04
# 	Improvement: 9.52e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 119ms. [ prep data: 62.5% (74.2ms); batching: 0.0% (11.9us); train: 34.5% (40.9ms); ltl: 0.8% (958us); lvl: 0.0% (7.63us); visualize: 0.2% (248us); terminate: 0.1% (91.6us); ]
#
# Epoch 65 (step 65):
# 	Learning rate: 1.67e+00
# 	Training loss: 7.75e-04
# 	Improvement: 1.32e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 107ms. [ prep data: 58.4% (62.5ms); batching: 0.0% (12.9us); train: 39.5% (42.2ms); ltl: 0.8% (864us); lvl: 0.0% (7.15us); visualize: 0.2% (213us); terminate: 0.1% (83.0us); ]
#
# Epoch 66 (step 66):
# 	Learning rate: 1.67e+00
# 	Training loss: 7.22e-04
# 	Improvement: 5.28e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 156ms. [ prep data: 72.8% (114ms); batching: 0.0% (13.1us); train: 26.4% (41.1ms); ltl: 0.5% (852us); lvl: 0.0% (5.25us); visualize: 0.1% (198us); terminate: 0.1% (110us); ]
#
# Epoch 67 (step 67):
# 	Learning rate: 1.67e+00
# 	Training loss: 7.12e-04
# 	Improvement: 9.78e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 170ms. [ prep data: 74.0% (126ms); batching: 0.0% (11.4us); train: 24.4% (41.4ms); ltl: 0.6% (962us); lvl: 0.0% (5.96us); visualize: 0.1% (236us); terminate: 0.1% (92.5us); ]
#
# Epoch 68 (step 68):
# 	Learning rate: 1.76e+00
# 	Training loss: 5.43e-04
# 	Improvement: 1.69e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 171ms. [ prep data: 74.0% (126ms); batching: 0.0% (10.0us); train: 24.3% (41.4ms); ltl: 0.6% (960us); lvl: 0.0% (5.48us); visualize: 0.1% (249us); terminate: 0.0% (76.1us); ]
#
# Epoch 69 (step 69):
# 	Learning rate: 1.76e+00
# 	Training loss: 5.62e-04
# 	Improvement: -1.84e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 110ms. [ prep data: 59.1% (65.2ms); batching: 0.0% (11.2us); train: 38.6% (42.6ms); ltl: 0.9% (1.04ms); lvl: 0.0% (6.68us); visualize: 0.3% (317us); terminate: 0.1% (78.0us); ]
#
# Epoch 70 (step 70):
# 	Learning rate: 1.76e+00
# 	Training loss: 5.50e-04
# 	Improvement: 1.13e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 118ms. [ prep data: 58.7% (69.2ms); batching: 0.0% (11.4us); train: 39.1% (46.1ms); ltl: 0.7% (775us); lvl: 0.0% (6.68us); visualize: 0.1% (169us); terminate: 0.1% (100us); ]
#
# Epoch 71 (step 71):
# 	Learning rate: 1.76e+00
# 	Training loss: 5.18e-04
# 	Improvement: 3.20e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 104ms. [ prep data: 63.7% (66.6ms); batching: 0.0% (12.2us); train: 34.8% (36.4ms); ltl: 0.9% (984us); lvl: 0.0% (5.48us); visualize: 0.2% (232us); terminate: 0.1% (76.5us); ]
#
# Epoch 72 (step 72):
# 	Learning rate: 1.76e+00
# 	Training loss: 4.58e-04
# 	Improvement: 6.05e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 169ms. [ prep data: 68.5% (116ms); batching: 0.0% (14.5us); train: 29.7% (50.3ms); ltl: 0.7% (1.15ms); lvl: 0.0% (7.87us); visualize: 0.1% (223us); terminate: 0.1% (103us); ]
#
# Epoch 73 (step 73):
# 	Learning rate: 1.76e+00
# 	Training loss: 4.56e-04
# 	Improvement: 2.07e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 139ms. [ prep data: 65.1% (90.1ms); batching: 0.0% (20.5us); train: 34.1% (47.2ms); ltl: 0.5% (728us); lvl: 0.0% (6.20us); visualize: 0.1% (163us); terminate: 0.1% (91.8us); ]
#
# Epoch 74 (step 74):
# 	Learning rate: 1.76e+00
# 	Training loss: 4.28e-04
# 	Improvement: 2.78e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 113ms. [ prep data: 61.9% (70.0ms); batching: 0.0% (16.9us); train: 36.8% (41.6ms); ltl: 0.7% (839us); lvl: 0.0% (7.15us); visualize: 0.3% (287us); terminate: 0.1% (96.3us); ]
#
# Epoch 75 (step 75):
# 	Learning rate: 1.85e+00
# 	Training loss: 3.58e-04
# 	Improvement: 6.97e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 124ms. [ prep data: 61.0% (75.7ms); batching: 0.0% (17.4us); train: 36.5% (45.3ms); ltl: 1.0% (1.22ms); lvl: 0.0% (8.11us); visualize: 0.2% (305us); terminate: 0.1% (126us); ]
#
# Epoch 76 (step 76):
# 	Learning rate: 1.85e+00
# 	Training loss: 3.68e-04
# 	Improvement: -9.23e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 170ms. [ prep data: 68.7% (117ms); batching: 0.0% (16.0us); train: 30.2% (51.3ms); ltl: 0.7% (1.24ms); lvl: 0.0% (9.30us); visualize: 0.2% (277us); terminate: 0.1% (111us); ]
#
# Epoch 77 (step 77):
# 	Learning rate: 1.85e+00
# 	Training loss: 3.49e-04
# 	Improvement: 1.81e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 135ms. [ prep data: 65.4% (88.2ms); batching: 0.0% (14.5us); train: 33.5% (45.2ms); ltl: 0.7% (916us); lvl: 0.0% (8.34us); visualize: 0.2% (227us); terminate: 0.1% (105us); ]
#
# Epoch 78 (step 78):
# 	Learning rate: 1.85e+00
# 	Training loss: 3.33e-04
# 	Improvement: 1.67e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 164ms. [ prep data: 65.9% (108ms); batching: 0.0% (17.2us); train: 32.8% (54.0ms); ltl: 0.5% (842us); lvl: 0.0% (7.87us); visualize: 0.1% (204us); terminate: 0.1% (106us); ]
#
# Epoch 79 (step 79):
# 	Learning rate: 1.85e+00
# 	Training loss: 3.26e-04
# 	Improvement: 6.97e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 131ms. [ prep data: 71.3% (93.2ms); batching: 0.0% (12.2us); train: 27.5% (36.0ms); ltl: 0.8% (1.02ms); lvl: 0.0% (7.15us); visualize: 0.2% (197us); terminate: 0.1% (112us); ]
#
# Epoch 80 (step 80):
# 	Learning rate: 1.85e+00
# 	Training loss: 3.44e-04
# 	Improvement: -1.78e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 132ms. [ prep data: 65.9% (86.9ms); batching: 0.0% (10.7us); train: 32.8% (43.2ms); ltl: 0.4% (571us); lvl: 0.0% (5.72us); visualize: 0.1% (146us); terminate: 0.1% (70.8us); ]
#
# Epoch 81 (step 81):
# 	Learning rate: 1.85e+00
# 	Training loss: 3.06e-04
# 	Improvement: 3.79e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 154ms. [ prep data: 75.2% (116ms); batching: 0.0% (12.4us); train: 23.4% (36.0ms); ltl: 0.5% (840us); lvl: 0.0% (7.15us); visualize: 0.1% (196us); terminate: 0.1% (86.1us); ]
#
# Epoch 82 (step 82):
# 	Learning rate: 1.85e+00
# 	Training loss: 3.05e-04
# 	Improvement: 7.84e-07
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 134ms. [ prep data: 61.9% (82.6ms); batching: 0.0% (11.2us); train: 35.9% (47.9ms); ltl: 0.7% (876us); lvl: 0.0% (7.87us); visualize: 0.2% (230us); terminate: 0.1% (98.2us); ]
#
# Epoch 83 (step 83):
# 	Learning rate: 1.85e+00
# 	Training loss: 2.89e-04
# 	Improvement: 1.62e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 102ms. [ prep data: 63.2% (64.7ms); batching: 0.0% (13.1us); train: 34.4% (35.2ms); ltl: 1.1% (1.11ms); lvl: 0.0% (6.20us); visualize: 0.2% (209us); terminate: 0.1% (80.1us); ]
#
# Epoch 84 (step 84):
# 	Learning rate: 1.85e+00
# 	Training loss: 2.70e-04
# 	Improvement: 1.92e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 106ms. [ prep data: 59.9% (63.4ms); batching: 0.0% (13.6us); train: 38.5% (40.8ms); ltl: 0.9% (957us); lvl: 0.0% (6.44us); visualize: 0.2% (226us); terminate: 0.1% (87.7us); ]
#
# Epoch 85 (step 85):
# 	Learning rate: 1.85e+00
# 	Training loss: 2.52e-04
# 	Improvement: 1.78e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 114ms. [ prep data: 67.5% (77.0ms); batching: 0.0% (11.7us); train: 31.1% (35.5ms); ltl: 0.9% (1.01ms); lvl: 0.0% (6.91us); visualize: 0.2% (257us); terminate: 0.1% (99.4us); ]
#
# Epoch 86 (step 86):
# 	Learning rate: 1.95e+00
# 	Training loss: 2.52e-04
# 	Improvement: -1.95e-07
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 142ms. [ prep data: 63.5% (90.3ms); batching: 0.0% (16.5us); train: 34.3% (48.8ms); ltl: 0.8% (1.19ms); lvl: 0.0% (6.91us); visualize: 0.2% (245us); terminate: 0.1% (160us); ]
#
# Epoch 87 (step 87):
# 	Learning rate: 1.95e+00
# 	Training loss: 2.27e-04
# 	Improvement: 2.54e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 148ms. [ prep data: 64.0% (94.5ms); batching: 0.0% (16.5us); train: 34.2% (50.5ms); ltl: 0.8% (1.15ms); lvl: 0.0% (6.91us); visualize: 0.2% (228us); terminate: 0.1% (94.9us); ]
#
# Epoch 88 (step 88):
# 	Learning rate: 1.95e+00
# 	Training loss: 2.27e-04
# 	Improvement: -2.72e-08
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 159ms. [ prep data: 72.4% (115ms); batching: 0.0% (15.5us); train: 26.6% (42.4ms); ltl: 0.6% (880us); lvl: 0.0% (9.06us); visualize: 0.1% (225us); terminate: 0.1% (109us); ]
#
# Epoch 89 (step 89):
# 	Learning rate: 1.95e+00
# 	Training loss: 2.21e-04
# 	Improvement: 5.32e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 158ms. [ prep data: 67.8% (107ms); batching: 0.0% (15.5us); train: 30.6% (48.2ms); ltl: 0.6% (875us); lvl: 0.0% (9.78us); visualize: 0.1% (224us); terminate: 0.1% (107us); ]
#
# Epoch 90 (step 90):
# 	Learning rate: 1.95e+00
# 	Training loss: 2.04e-04
# 	Improvement: 1.75e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 156ms. [ prep data: 69.1% (108ms); batching: 0.0% (15.7us); train: 29.1% (45.4ms); ltl: 0.6% (971us); lvl: 0.0% (6.91us); visualize: 0.2% (250us); terminate: 0.1% (95.4us); ]
#
# Epoch 91 (step 91):
# 	Learning rate: 1.95e+00
# 	Training loss: 2.00e-04
# 	Improvement: 4.03e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 143ms. [ prep data: 59.3% (84.9ms); batching: 0.0% (15.7us); train: 37.6% (53.9ms); ltl: 1.5% (2.16ms); lvl: 0.0% (10.0us); visualize: 0.4% (565us); terminate: 0.1% (115us); ]
#
# Epoch 92 (step 92):
# 	Learning rate: 1.95e+00
# 	Training loss: 1.94e-04
# 	Improvement: 5.32e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 129ms. [ prep data: 63.3% (81.4ms); batching: 0.0% (15.3us); train: 35.0% (45.0ms); ltl: 0.7% (961us); lvl: 0.0% (8.82us); visualize: 0.2% (220us); terminate: 0.1% (124us); ]
#
# Epoch 93 (step 93):
# 	Learning rate: 1.95e+00
# 	Training loss: 1.81e-04
# 	Improvement: 1.35e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 147ms. [ prep data: 70.4% (104ms); batching: 0.0% (13.6us); train: 27.7% (40.7ms); ltl: 0.6% (855us); lvl: 0.0% (8.82us); visualize: 0.1% (192us); terminate: 0.1% (110us); ]
#
# Epoch 94 (step 94):
# 	Learning rate: 2.05e+00
# 	Training loss: 1.82e-04
# 	Improvement: -1.42e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 167ms. [ prep data: 67.0% (112ms); batching: 0.0% (15.5us); train: 31.9% (53.5ms); ltl: 0.7% (1.16ms); lvl: 0.0% (8.34us); visualize: 0.2% (262us); terminate: 0.1% (100us); ]
#
# Epoch 95 (step 95):
# 	Learning rate: 2.05e+00
# 	Training loss: 1.70e-04
# 	Improvement: 1.29e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 115ms. [ prep data: 59.1% (68.1ms); batching: 0.0% (14.5us); train: 38.3% (44.1ms); ltl: 0.7% (862us); lvl: 0.0% (9.06us); visualize: 0.2% (281us); terminate: 0.1% (98.5us); ]
#
# Epoch 96 (step 96):
# 	Learning rate: 2.05e+00
# 	Training loss: 1.69e-04
# 	Improvement: 9.60e-07
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 125ms. [ prep data: 55.7% (69.5ms); batching: 0.0% (17.2us); train: 42.2% (52.6ms); ltl: 0.7% (860us); lvl: 0.0% (8.58us); visualize: 0.2% (223us); terminate: 0.1% (101us); ]
#
# Epoch 97 (step 97):
# 	Learning rate: 2.05e+00
# 	Training loss: 1.67e-04
# 	Improvement: 1.85e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 109ms. [ prep data: 59.6% (64.8ms); batching: 0.0% (15.0us); train: 38.0% (41.3ms); ltl: 0.8% (906us); lvl: 0.0% (8.82us); visualize: 0.2% (194us); terminate: 0.1% (103us); ]
#
# Epoch 98 (step 98):
# 	Learning rate: 2.05e+00
# 	Training loss: 1.59e-04
# 	Improvement: 7.84e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 115ms. [ prep data: 58.3% (67.0ms); batching: 0.0% (16.9us); train: 39.8% (45.7ms); ltl: 0.7% (858us); lvl: 0.0% (8.82us); visualize: 0.2% (208us); terminate: 0.1% (107us); ]
#
# Epoch 99 (step 99):
# 	Learning rate: 2.05e+00
# 	Training loss: 1.54e-04
# 	Improvement: 5.01e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 114ms. [ prep data: 62.9% (71.6ms); batching: 0.0% (16.5us); train: 35.8% (40.7ms); ltl: 0.8% (878us); lvl: 0.0% (8.58us); visualize: 0.2% (223us); terminate: 0.1% (95.4us); ]
#
# Epoch 100 (step 100):
# 	Learning rate: 2.16e+00
# 	Saving SESO checkpoint.
# 	Achieved lowest training loss.
# 	Saving LTL checkpoint.
# 	Saving LTL summary (train).
# 	Updating Tensorboard images.
# 	Saving SESO visualizations.
# 	Training loss: 1.56e-04
# 	Improvement: -1.71e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 1.86s. [ prep data: 3.6% (67.2ms); batching: 0.0% (16.9us); train: 2.6% (48.4ms); seso: 20.9% (388ms); ltl: 21.0% (390ms); lvl: 0.0% (6.44us); visualize: 51.9% (964ms); terminate: 0.0% (112us); ]
#
# Epoch 101 (step 101):
# 	Learning rate: 2.16e+00
# 	Training loss: 1.47e-04
# 	Improvement: 8.10e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 144ms. [ prep data: 71.5% (103ms); batching: 0.0% (12.9us); train: 27.4% (39.5ms); ltl: 0.7% (1.01ms); lvl: 0.0% (6.44us); visualize: 0.2% (260us); terminate: 0.1% (83.7us); ]
#
# Epoch 102 (step 102):
# 	Learning rate: 2.16e+00
# 	Training loss: 1.48e-04
# 	Improvement: -8.87e-07
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 138ms. [ prep data: 70.8% (97.4ms); batching: 0.0% (12.9us); train: 28.1% (38.7ms); ltl: 0.7% (980us); lvl: 0.0% (5.96us); visualize: 0.2% (245us); terminate: 0.1% (76.8us); ]
#
# Epoch 103 (step 103):
# 	Learning rate: 2.16e+00
# 	Training loss: 1.45e-04
# 	Improvement: 3.10e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 132ms. [ prep data: 68.5% (90.2ms); batching: 0.0% (10.5us); train: 30.4% (40.0ms); ltl: 0.7% (958us); lvl: 0.0% (5.72us); visualize: 0.2% (238us); terminate: 0.1% (78.2us); ]
#
# Epoch 104 (step 104):
# 	Learning rate: 2.16e+00
# 	Training loss: 1.41e-04
# 	Improvement: 4.69e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 116ms. [ prep data: 60.7% (70.2ms); batching: 0.0% (10.5us); train: 36.9% (42.7ms); ltl: 0.9% (984us); lvl: 0.0% (8.34us); visualize: 0.2% (207us); terminate: 0.1% (103us); ]
#
# Epoch 105 (step 105):
# 	Learning rate: 2.16e+00
# 	Training loss: 1.38e-04
# 	Improvement: 2.74e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 128ms. [ prep data: 69.4% (88.9ms); batching: 0.0% (13.4us); train: 29.6% (37.9ms); ltl: 0.7% (850us); lvl: 0.0% (7.39us); visualize: 0.2% (192us); terminate: 0.1% (90.8us); ]
#
# Epoch 106 (step 106):
# 	Learning rate: 2.16e+00
# 	Training loss: 1.33e-04
# 	Improvement: 4.76e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 174ms. [ prep data: 73.9% (129ms); batching: 0.0% (15.3us); train: 24.7% (43.1ms); ltl: 0.5% (845us); lvl: 0.0% (6.68us); visualize: 0.1% (215us); terminate: 0.0% (79.2us); ]
#
# Epoch 107 (step 107):
# 	Learning rate: 2.16e+00
# 	Training loss: 1.31e-04
# 	Improvement: 2.45e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 108ms. [ prep data: 60.8% (65.8ms); batching: 0.0% (13.4us); train: 37.8% (40.9ms); ltl: 0.8% (899us); lvl: 0.0% (7.39us); visualize: 0.2% (236us); terminate: 0.1% (88.2us); ]
#
# Epoch 108 (step 108):
# 	Learning rate: 2.27e+00
# 	Training loss: 1.28e-04
# 	Improvement: 2.57e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 120ms. [ prep data: 60.6% (72.8ms); batching: 0.0% (11.4us); train: 37.1% (44.5ms); ltl: 0.8% (923us); lvl: 0.0% (7.15us); visualize: 0.3% (311us); terminate: 0.1% (81.8us); ]
#
# Epoch 109 (step 109):
# 	Learning rate: 2.27e+00
# 	Training loss: 1.28e-04
# 	Improvement: 2.74e-07
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 122ms. [ prep data: 64.8% (78.8ms); batching: 0.0% (11.0us); train: 32.9% (40.0ms); ltl: 1.0% (1.21ms); lvl: 0.0% (6.91us); visualize: 0.2% (262us); terminate: 0.1% (121us); ]
#
# Epoch 110 (step 110):
# 	Learning rate: 2.27e+00
# 	Training loss: 1.32e-04
# 	Improvement: -4.16e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 123ms. [ prep data: 54.1% (66.5ms); batching: 0.0% (12.2us); train: 42.9% (52.9ms); ltl: 1.2% (1.46ms); lvl: 0.0% (7.15us); visualize: 0.2% (244us); terminate: 0.1% (80.8us); ]
#
# Epoch 111 (step 111):
# 	Learning rate: 2.27e+00
# 	Training loss: 1.41e-04
# 	Improvement: -8.72e-06
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 186ms. [ prep data: 75.3% (140ms); batching: 0.0% (14.3us); train: 23.5% (43.7ms); ltl: 0.5% (895us); lvl: 0.0% (7.39us); visualize: 0.1% (215us); terminate: 0.0% (83.7us); ]
#
# Epoch 112 (step 112):
# 	Learning rate: 2.27e+00
# 	Training loss: 1.66e-04
# 	Improvement: -2.52e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 183ms. [ prep data: 68.8% (126ms); batching: 0.0% (12.6us); train: 30.4% (55.7ms); ltl: 0.5% (906us); lvl: 0.0% (7.87us); visualize: 0.1% (240us); terminate: 0.1% (102us); ]
#
# Epoch 113 (step 113):
# 	Learning rate: 2.16e+00
# 	Training loss: 2.22e-04
# 	Improvement: -5.63e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 235ms. [ prep data: 59.7% (140ms); batching: 0.0% (14.8us); train: 38.7% (91.2ms); ltl: 0.6% (1.37ms); lvl: 0.0% (8.34us); visualize: 0.1% (324us); terminate: 0.0% (95.1us); ]
#
# Epoch 114 (step 114):
# 	Learning rate: 2.16e+00
# 	Training loss: 3.14e-04
# 	Improvement: -9.15e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 206ms. [ prep data: 67.5% (139ms); batching: 0.0% (15.0us); train: 31.8% (65.7ms); ltl: 0.4% (782us); lvl: 0.0% (7.87us); visualize: 0.1% (166us); terminate: 0.0% (90.6us); ]
#
# Epoch 115 (step 115):
# 	Learning rate: 2.16e+00
# 	Training loss: 4.32e-04
# 	Improvement: -1.18e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 244ms. [ prep data: 65.6% (160ms); batching: 0.0% (14.5us); train: 33.5% (82.0ms); ltl: 0.6% (1.40ms); lvl: 0.0% (7.39us); visualize: 0.1% (300us); terminate: 0.0% (103us); ]
#
# Epoch 116 (step 116):
# 	Learning rate: 2.16e+00
# 	Training loss: 5.81e-04
# 	Improvement: -1.49e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 243ms. [ prep data: 62.8% (153ms); batching: 0.0% (13.8us); train: 36.4% (88.4ms); ltl: 0.4% (941us); lvl: 0.0% (7.63us); visualize: 0.1% (177us); terminate: 0.0% (111us); ]
#
# Epoch 117 (step 117):
# 	Learning rate: 2.16e+00
# 	Training loss: 7.73e-04
# 	Improvement: -1.92e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 235ms. [ prep data: 64.4% (151ms); batching: 0.0% (15.5us); train: 34.3% (80.5ms); ltl: 0.4% (1.02ms); lvl: 0.0% (6.91us); visualize: 0.1% (240us); terminate: 0.0% (88.5us); ]
#
# Epoch 118 (step 118):
# 	Learning rate: 2.05e+00
# 	Training loss: 1.00e-03
# 	Improvement: -2.28e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 221ms. [ prep data: 62.2% (138ms); batching: 0.0% (14.3us); train: 36.5% (80.9ms); ltl: 0.3% (752us); lvl: 0.0% (7.15us); visualize: 0.1% (194us); terminate: 0.0% (95.6us); ]
#
# Epoch 119 (step 119):
# 	Learning rate: 2.05e+00
# 	Training loss: 1.05e-03
# 	Improvement: -4.41e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 238ms. [ prep data: 60.9% (145ms); batching: 0.0% (14.3us); train: 37.6% (89.3ms); ltl: 0.6% (1.33ms); lvl: 0.0% (7.39us); visualize: 0.1% (320us); terminate: 0.0% (97.8us); ]
#
# Epoch 120 (step 120):
# 	Learning rate: 2.05e+00
# 	Training loss: 7.50e-04
# 	Improvement: 2.95e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 212ms. [ prep data: 66.8% (142ms); batching: 0.0% (17.9us); train: 32.4% (68.7ms); ltl: 0.5% (1.11ms); lvl: 0.0% (7.39us); visualize: 0.1% (251us); terminate: 0.1% (108us); ]
#
# Epoch 121 (step 121):
# 	Learning rate: 2.05e+00
# 	Training loss: 3.46e-04
# 	Improvement: 4.04e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 241ms. [ prep data: 68.7% (165ms); batching: 0.0% (14.1us); train: 30.1% (72.4ms); ltl: 0.5% (1.13ms); lvl: 0.0% (7.63us); visualize: 0.1% (319us); terminate: 0.0% (102us); ]
#
# Epoch 122 (step 122):
# 	Learning rate: 2.05e+00
# 	Training loss: 1.15e-04
# 	Improvement: 2.31e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 213ms. [ prep data: 64.6% (137ms); batching: 0.0% (13.6us); train: 33.9% (72.1ms); ltl: 0.6% (1.32ms); lvl: 0.0% (8.34us); visualize: 0.1% (299us); terminate: 0.0% (101us); ]
#
# Epoch 123 (step 123):
# 	Learning rate: 2.05e+00
# 	Training loss: 1.72e-04
# 	Improvement: -5.75e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 207ms. [ prep data: 66.2% (137ms); batching: 0.0% (14.5us); train: 33.2% (68.8ms); ltl: 0.4% (732us); lvl: 0.0% (7.63us); visualize: 0.1% (161us); terminate: 0.0% (88.5us); ]
#
# Epoch 124 (step 124):
# 	Learning rate: 2.05e+00
# 	Training loss: 4.03e-04
# 	Improvement: -2.30e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 241ms. [ prep data: 66.8% (161ms); batching: 0.0% (16.0us); train: 32.2% (77.7ms); ltl: 0.4% (949us); lvl: 0.0% (6.68us); visualize: 0.1% (223us); terminate: 0.0% (93.9us); ]
#
# Epoch 125 (step 125):
# 	Learning rate: 2.05e+00
# 	Training loss: 6.07e-04
# 	Improvement: -2.04e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 221ms. [ prep data: 59.3% (131ms); batching: 0.1% (292us); train: 39.8% (88.1ms); ltl: 0.5% (1.00ms); lvl: 0.0% (6.91us); visualize: 0.1% (308us); terminate: 0.0% (93.7us); ]
#
# Epoch 126 (step 126):
# 	Learning rate: 2.05e+00
# 	Training loss: 6.44e-04
# 	Improvement: -3.69e-05
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 243ms. [ prep data: 57.1% (139ms); batching: 0.0% (12.4us); train: 42.0% (102ms); ltl: 0.6% (1.51ms); lvl: 0.0% (7.39us); visualize: 0.2% (377us); terminate: 0.0% (95.4us); ]
#
# Epoch 127 (step 127):
# 	Learning rate: 1.95e+00
# 	Training loss: 5.02e-04
# 	Improvement: 1.42e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 396ms. [ prep data: 75.1% (298ms); batching: 0.0% (17.4us); train: 24.0% (95.2ms); ltl: 0.2% (979us); lvl: 0.0% (7.39us); visualize: 0.1% (280us); terminate: 0.0% (94.2us); ]
#
# Epoch 128 (step 128):
# 	Learning rate: 1.95e+00
# 	Training loss: 2.40e-04
# 	Improvement: 2.62e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 382ms. [ prep data: 66.3% (253ms); batching: 0.0% (11.9us); train: 32.6% (124ms); ltl: 0.5% (1.80ms); lvl: 0.0% (8.58us); visualize: 0.1% (387us); terminate: 0.0% (119us); ]
#
# Epoch 129 (step 129):
# 	Learning rate: 1.95e+00
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/training/saver.py:1052: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Stopping optimization: loss meets convergence criteria.
# 	Training loss: 9.56e-05
# 	Improvement: 1.44e-04
# 	Logging to: ./logs/06862fd7da
# 	Epoch time: 405ms. [ prep data: 73.9% (299ms); batching: 0.0% (16.0us); train: 25.1% (102ms); ltl: 0.2% (998us); lvl: 0.0% (7.63us); visualize: 0.1% (243us); terminate: 0.3% (1.14ms); ]
#
# 	Saving SESO checkpoint.
# 	Saving .done file.
#
# Closing training:
# 	Updating Tensorboard images.
# 	Saving SESO visualizations.
# 	Saving LVL summary (train).
# 	Saving LVL predictions (train).
# 	Updating Tensorboard images.
# 	Saving LVL visualizations.
# 	Saving LTL summary (train).
# 	Saving LTL predictions (train).
# 	Updating Tensorboard images.
# 	Saving LTL visualizations.
#
# Total run time time: 40.9s.
# 	0.0% (4.75ms): setup_hps
# 	0.0% (4.64ms): _setup_run_dir
# 	0.0% (1.59ms): set_random_seed
# 	0.0% (251us): init AdaptiveLearningRate
# 	0.0% (16.2us): init AdaptiveGradNormClip
# 	0.2% (71.2ms): _setup_records
# 	4.0% (1.64s): _setup_model
# 	6.6% (2.70s): _setup_optimizer
# 	0.0% (94.2us): _setup_visualizations
# 	0.8% (321ms): _setup_tensorboard
# 	0.6% (257ms): _setup_savers
# 	0.1% (24.7ms): _setup_session
# 	1.8% (724ms): initialize_or_restore
# 	1.5% (597ms): _setup_training
# 	6.1% (2.48s): init ckpt
# 	70.6% (28.9s): train
# 	7.9% (3.21s): close_training

# %% [markdown]
# ## STEP 2: Find, analyze, and visualize the fixed points of the trained RNN

# %%
def find_fixed_points(model, valid_predictions):
    ''' Find, analyze, and visualize the fixed points of the trained RNN.

    Args:
        model: FlipFlop object.

            Trained RNN model, as returned by train_FlipFlop().

        valid_predictions: dict.

            Model predictions on validation trials, as returned by
            train_FlipFlop().

    Returns:
        None.
    '''

    '''Initial states are sampled from states observed during realistic
    behavior of the network. Because a well-trained network transitions
    instantaneously from one stable state to another, observed networks states
    spend little if any time near the unstable fixed points. In order to
    identify ALL fixed points, noise must be added to the initial states
    before handing them to the fixed point finder. In this example, the noise
    needed is rather large, which can lead to identifying fixed points well
    outside of the domain of states observed in realistic behavior of the
    network--such fixed points can be safely ignored when interpreting the
    dynamical landscape (but can throw visualizations).'''

    NOISE_SCALE = 0.5 # Standard deviation of noise added to initial states
    N_INITS = 1024 # The number of initial states to provide

    n_bits = model.hps.data_hps['n_bits']
    is_lstm = model.hps.rnn_type == 'lstm'

    '''Fixed point finder hyperparameters. See FixedPointFinder.py for detailed
    descriptions of available hyperparameters.'''
    fpf_hps = {}

    # Setup the fixed point finder
    fpf = FixedPointFinder(model.rnn_cell, model.session, **fpf_hps)

    # Study the system in the absence of input pulses (e.g., all inputs are 0)
    inputs = np.zeros([1,n_bits])

    '''Draw random, noise corrupted samples of those state trajectories
    to use as initial states for the fixed point optimizations.'''
    initial_states = fpf.sample_states(valid_predictions['state'],
        n_inits=N_INITS,
        noise_scale=NOISE_SCALE)

    # Run the fixed point finder
    unique_fps, all_fps = fpf.find_fixed_points(initial_states, inputs)
    
    return unique_fps, all_fps

# %%
unique_fps, all_fps = find_fixed_points(model, valid_predictions)
# Out:
# Searching for fixed points from 1024 initial states.
#
# 	Finding fixed points via joint optimization.
# 	Optimization complete to desired tolerance.
# 		526 iters
# 		q = 1.37e-14 +/- 2.34e-14
# 		dq = 1.58e-14 +/- 2.79e-13
# 		learning rate = 1.96e+01
# 		avg iter time = 3.41e-03 sec
# 	Identified 27 unique fixed points.
# 		initial_states: 0 outliers detected (of 1024).
# 		fixed points: 0 outliers detected (of 27).
# 	Computing recurrent Jacobian at 27 unique fixed points.
# 	Computing input Jacobian at 27 unique fixed points.
# 	Decomposing Jacobians in a single batch.
# 	Sorting by Eigenvalue magnitude.
# 	Fixed point finding complete.

# %%
import matplotlib.pyplot as plt

idx = 2

fp = unique_fps[idx]

xstar = fp.xstar
J = fp.J_xstar
n_states = fp.n_states

e_vals = fp.eigval_J_xstar[0]
e_vecs = fp.eigvec_J_xstar[0]

sorted_e_val_idx = np.argsort(np.abs(e_vals))

plt.plot(e_vals.real,e_vals.imag,'.',alpha = .5)
circle1 = plt.Circle((0, 0), 1, color='k',alpha = .05)
plt.gca().add_patch(circle1)
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('square')
# Out:
# (-1.1676162958145142, 2.519942212104797, -1.1, 2.587558507919311)

# %%
# Determine stability of fixed points
is_stable = np.all(np.abs(e_vals) < 1.0)
print(is_stable)
# Out:
# False

# %%
unique_fps[0]

# %%
# Visualize identified fixed points with overlaid RNN state trajectories
# All visualized in the 3D PCA space fit the the example RNN states.
which_fps = [0]
fig = plot_fps(unique_fps[which_fps], valid_predictions['state'],
    plot_batch_idx=list(range(30)),
    plot_start_time=10)

model.save_visualizations(figs={'fixed_points': fig})
# Out:
# 	Updating Tensorboard images.
# 	Saving SESO visualizations.
